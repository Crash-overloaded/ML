# %% [markdown]
# <a href="https://colab.research.google.com/github/Crash-overloaded/ML/blob/master/Dat_Vis4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sb
from bs4 import BeautifulSoup 
import matplotlib.pyplot as plt
import requests

# %%
url="https://en.wikipedia.org/wiki/Machine_learning"
response=requests.get(url)

# %%
data=response.text
soup=BeautifulSoup(data,'lxml')

# %%
a=[]
for i in soup.find_all('p'):
  for j in i.text.split(" "): 
    a.append(j)
di={}
for i in a:
  di.update({i:a.count(i)})
from heapq import nlargest
largest=nlargest(20,di.values())
largest_words=nlargest(20,di,key=di.get)
# Out:
# {'Machine': 13,
#  'learning': 112,
#  '(ML)': 1,
#  'is': 83,
#  'the': 265,
#  'scientific': 2,
#  'study': 5,
#  'of': 181,
#  'algorithms': 42,
#  'and': 146,
#  'statistical': 6,
#  'models': 14,
#  'that': 73,
#  'computer': 9,
#  'systems': 9,
#  'use': 10,
#  'in': 110,
#  'order': 6,
#  'to': 155,
#  'perform': 10,
#  'a': 177,
#  'specific': 5,
#  'task': 4,
#  'effectively': 1,
#  'without': 7,
#  'using': 11,
#  'explicit': 2,
#  'instructions,': 1,
#  'relying': 2,
#  'on': 34,
#  'patterns': 3,
#  'inference': 2,
#  'instead.': 1,
#  'It': 8,
#  'seen': 2,
#  'as': 49,
#  'subset': 2,
#  'artificial': 16,
#  'intelligence.': 2,
#  'build': 3,
#  'mathematical': 10,
#  'model': 25,
#  'based': 7,
#  'sample': 3,
#  'data,': 15,
#  'known': 11,
#  '"training': 1,
#  'data",': 1,
#  'make': 5,
#  'predictions': 5,
#  'or': 40,
#  'decisions': 3,
#  'being': 5,
#  'explicitly': 2,
#  'programmed': 2,
#  'task.[1][2]:2': 1,
#  'are': 58,
#  'used': 26,
#  'wide': 1,
#  'variety': 3,
#  'applications,': 1,
#  'such': 15,
#  'email': 1,
#  'filtering,': 2,
#  'vision,': 2,
#  'where': 8,
#  'it': 14,
#  'infeasible': 1,
#  'develop': 2,
#  'an': 29,
#  'algorithm': 16,
#  'instructions': 1,
#  'for': 36,
#  'performing': 5,
#  'task.': 1,
#  'closely': 3,
#  'related': 7,
#  'computational': 4,
#  'statistics,': 2,
#  'which': 14,
#  'focuses': 4,
#  'making': 1,
#  'computers.': 1,
#  'The': 19,
#  'optimization': 3,
#  'delivers': 1,
#  'methods,': 5,
#  'theory': 3,
#  'application': 4,
#  'domains': 2,
#  'field': 11,
#  'machine': 62,
#  'learning.': 9,
#  'Data': 3,
#  'mining': 7,
#  'within': 6,
#  'learning,': 18,
#  'exploratory': 1,
#  'data': 48,
#  'analysis': 6,
#  'through': 3,
#  'unsupervised': 8,
#  'learning.[3][4]': 1,
#  'In': 34,
#  'its': 9,
#  'across': 2,
#  'business': 1,
#  'problems,': 2,
#  'also': 17,
#  'referred': 2,
#  'predictive': 3,
#  'analytics.\n': 1,
#  'name': 2,
#  'was': 12,
#  'coined': 2,
#  '1959': 2,
#  'by': 33,
#  'Arthur': 2,
#  'Samuel.[5]': 1,
#  'Tom': 1,
#  'M.': 1,
#  'Mitchell': 1,
#  'provided': 2,
#  'widely': 1,
#  'quoted,': 1,
#  'more': 8,
#  'formal': 1,
#  'definition': 4,
#  'studied': 2,
#  'field:': 1,
#  '"A': 1,
#  'program': 5,
#  'said': 2,
#  'learn': 9,
#  'from': 41,
#  'experience': 2,
#  'E': 1,
#  'with': 27,
#  'respect': 3,
#  'some': 11,
#  'class': 6,
#  'tasks': 7,
#  'T': 1,
#  'performance': 10,
#  'measure': 2,
#  'P': 1,
#  'if': 6,
#  'at': 7,
#  'T,': 1,
#  'measured': 1,
#  'P,': 1,
#  '': 5,
#  'improves': 2,
#  'E."[6]': 1,
#  'This': 10,
#  'concerned': 3,
#  'offers': 1,
#  'fundamentally': 1,
#  'operational': 1,
#  'rather': 2,
#  'than': 4,
#  'defining': 2,
#  'cognitive': 1,
#  'terms.': 1,
#  'follows': 1,
#  'Alan': 1,
#  "Turing's": 2,
#  'proposal': 2,
#  'his': 1,
#  'paper': 1,
#  '"Computing': 1,
#  'Machinery': 1,
#  'Intelligence",': 1,
#  'question': 2,
#  '"Can': 2,
#  'machines': 5,
#  'think?"': 1,
#  'replaced': 1,
#  'do': 5,
#  'what': 3,
#  'we': 2,
#  '(as': 1,
#  'thinking': 2,
#  'entities)': 1,
#  'can': 28,
#  'do?".[7]': 1,
#  'various': 5,
#  'characteristics': 1,
#  'could': 3,
#  'be': 36,
#  'possessed': 1,
#  'implications': 1,
#  'constructing': 1,
#  'one': 11,
#  'exposed.\n': 1,
#  '\n': 2,
#  'classified': 2,
#  'into': 9,
#  'several': 2,
#  'broad': 2,
#  'categories.': 1,
#  'supervised': 13,
#  'builds': 3,
#  'set': 27,
#  'contains': 5,
#  'both': 3,
#  'inputs': 11,
#  'desired': 5,
#  'outputs.': 1,
#  'For': 10,
#  'example,': 8,
#  'were': 9,
#  'determining': 1,
#  'whether': 3,
#  'image': 5,
#  'contained': 2,
#  'certain': 3,
#  'object,': 2,
#  'training': 42,
#  'would': 8,
#  'include': 8,
#  'images': 1,
#  'object': 1,
#  '(the': 5,
#  'input),': 1,
#  'each': 7,
#  'have': 17,
#  'label': 2,
#  'output)': 1,
#  'designating': 1,
#  'object.': 1,
#  'special': 2,
#  'cases,': 1,
#  'input': 11,
#  'may': 11,
#  'only': 7,
#  'partially': 1,
#  'available,': 1,
#  'restricted': 3,
#  'feedback.[clarification': 1,
#  'needed]': 1,
#  'Semi-supervised': 2,
#  'incomplete': 1,
#  'portion': 1,
#  "doesn't": 1,
#  'labels.\n': 1,
#  'Classification': 4,
#  'regression': 4,
#  'types': 3,
#  'when': 6,
#  'outputs': 5,
#  'limited': 3,
#  'values.': 1,
#  'classification': 10,
#  'filters': 1,
#  'emails,': 2,
#  'incoming': 1,
#  'email,': 1,
#  'output': 7,
#  'folder': 1,
#  'file': 1,
#  'email.': 1,
#  'identifies': 1,
#  'spam': 1,
#  'prediction': 2,
#  'either': 4,
#  '"spam"': 1,
#  '"not': 1,
#  'spam",': 1,
#  'represented': 9,
#  'Boolean': 1,
#  'values': 3,
#  'true': 2,
#  'false.': 1,
#  'Regression': 1,
#  'named': 1,
#  'their': 15,
#  'continuous': 4,
#  'outputs,': 1,
#  'meaning': 3,
#  'they': 8,
#  'any': 6,
#  'value': 4,
#  'range.': 2,
#  'Examples': 3,
#  'temperature,': 1,
#  'length,': 1,
#  'price': 1,
#  'object.\n': 1,
#  'no': 2,
#  'labels.': 3,
#  'Unsupervised': 4,
#  'find': 4,
#  'structure': 3,
#  'like': 6,
#  'grouping': 2,
#  'clustering': 3,
#  'points.': 2,
#  'discover': 3,
#  'group': 1,
#  'categories,': 2,
#  'feature': 7,
#  'Dimensionality': 1,
#  'reduction': 1,
#  'process': 5,
#  'reducing': 2,
#  'number': 1,
#  '"features",': 1,
#  'inputs,': 2,
#  'data.': 9,
#  'Active': 1,
#  'access': 2,
#  '(training': 1,
#  'labels)': 1,
#  'budget,': 1,
#  'optimize': 1,
#  'choice': 1,
#  'will': 8,
#  'acquire': 2,
#  'When': 2,
#  'interactively,': 1,
#  'these': 10,
#  'presented': 1,
#  'human': 6,
#  'user': 2,
#  'labeling.': 1,
#  'Reinforcement': 4,
#  'given': 4,
#  'feedback': 1,
#  'form': 1,
#  'positive': 3,
#  'negative': 3,
#  'reinforcement': 3,
#  'dynamic': 3,
#  'environment,': 1,
#  'autonomous': 2,
#  'vehicles': 2,
#  'play': 2,
#  'game': 3,
#  'against': 4,
#  'opponent.[2]:3': 1,
#  'Other': 3,
#  'specialized': 1,
#  'topic': 1,
#  'modeling,': 1,
#  'natural': 3,
#  'language': 4,
#  'documents': 2,
#  'finds': 1,
#  'other': 11,
#  'cover': 1,
#  'similar': 3,
#  'topics.': 1,
#  'unobservable': 1,
#  'probability': 3,
#  'density': 4,
#  'function': 7,
#  'estimation': 3,
#  'problems.': 1,
#  'Meta': 1,
#  'own': 2,
#  'inductive': 4,
#  'bias': 3,
#  'previous': 2,
#  'experience.': 1,
#  'developmental': 1,
#  'robotics,': 1,
#  'robot': 1,
#  'generate': 2,
#  'sequences': 2,
#  'experiences,': 1,
#  'curriculum,': 1,
#  'cumulatively': 1,
#  'new': 9,
#  'skills': 1,
#  'self-guided': 1,
#  'exploration': 1,
#  'social': 2,
#  'interaction': 1,
#  'humans.': 1,
#  'These': 1,
#  'robots': 1,
#  'guidance': 1,
#  'mechanisms': 1,
#  'active': 1,
#  'maturation,': 1,
#  'motor': 1,
#  'synergies,': 1,
#  'imitation.[clarification': 1,
#  'needed]\n': 1,
#  'Samuel,': 1,
#  'American': 1,
#  'pioneer': 1,
#  'gaming': 1,
#  'intelligence,': 2,
#  'term': 4,
#  '"Machine': 1,
#  'Learning"': 1,
#  'while': 7,
#  'IBM[8].': 1,
#  '\nAs': 1,
#  'endeavour,': 1,
#  'grew': 1,
#  'out': 3,
#  'quest': 1,
#  'Already': 1,
#  'early': 1,
#  'days': 1,
#  'AI': 4,
#  'academic': 1,
#  'discipline,': 1,
#  'researchers': 3,
#  'interested': 1,
#  'having': 3,
#  'They': 2,
#  'attempted': 1,
#  'approach': 6,
#  'problem': 4,
#  'symbolic': 2,
#  'well': 3,
#  'then': 8,
#  'termed': 1,
#  '"neural': 1,
#  'networks";': 1,
#  'mostly': 1,
#  'perceptrons': 1,
#  'later': 1,
#  'found': 4,
#  'reinventions': 1,
#  'generalized': 1,
#  'linear': 4,
#  'statistics.[9]': 1,
#  'Probabilistic': 2,
#  'reasoning': 1,
#  'employed,': 1,
#  'especially': 2,
#  'automated': 2,
#  'medical': 5,
#  'diagnosis.[10]:488\n': 1,
#  'However,': 4,
#  'increasing': 3,
#  'emphasis': 1,
#  'logical,': 1,
#  'knowledge-based': 1,
#  'caused': 1,
#  'rift': 1,
#  'between': 11,
#  'plagued': 1,
#  'theoretical': 4,
#  'practical': 2,
#  'problems': 7,
#  'acquisition': 1,
#  'representation.[10]:488': 1,
#  'By': 1,
#  '1980,': 1,
#  'expert': 1,
#  'had': 5,
#  'come': 2,
#  'dominate': 1,
#  'AI,': 3,
#  'statistics': 4,
#  'favor.[11]': 1,
#  'Work': 1,
#  'symbolic/knowledge-based': 1,
#  'did': 1,
#  'continue': 1,
#  'leading': 3,
#  'logic': 7,
#  'programming,': 1,
#  'but': 13,
#  'line': 1,
#  'research': 4,
#  'now': 1,
#  'outside': 2,
#  'proper,': 1,
#  'pattern': 2,
#  'recognition': 1,
#  'information': 5,
#  'retrieval.[10]:708–710;': 1,
#  '755': 1,
#  'Neural': 1,
#  'networks': 6,
#  'been': 16,
#  'abandoned': 1,
#  'science': 3,
#  'around': 1,
#  'same': 6,
#  'time.': 3,
#  'line,': 1,
#  'too,': 1,
#  'continued': 1,
#  'AI/CS': 1,
#  'field,': 2,
#  '"connectionism",': 1,
#  'disciplines': 1,
#  'including': 4,
#  'Hopfield,': 1,
#  'Rumelhart': 1,
#  'Hinton.': 1,
#  'Their': 1,
#  'main': 1,
#  'success': 1,
#  'came': 1,
#  'mid-1980s': 1,
#  'reinvention': 1,
#  'backpropagation.[10]:25\n': 1,
#  'reorganized': 1,
#  'separate': 3,
#  'started': 1,
#  'flourish': 1,
#  '1990s.': 1,
#  'changed': 2,
#  'goal': 4,
#  'achieving': 1,
#  'intelligence': 2,
#  'tackling': 1,
#  'solvable': 1,
#  'nature.': 1,
#  'shifted': 1,
#  'focus': 1,
#  'away': 1,
#  'approaches': 4,
#  'inherited': 1,
#  'toward': 1,
#  'methods': 10,
#  'borrowed': 1,
#  'theory.[11]': 1,
#  'benefited': 1,
#  'availability': 1,
#  'digitized': 1,
#  'information,': 2,
#  'ability': 3,
#  'distribute': 1,
#  'via': 1,
#  'Internet.\n': 1,
#  'often': 10,
#  'employ': 1,
#  'overlap': 1,
#  'significantly,': 1,
#  'prediction,': 1,
#  'properties': 2,
#  'learned': 10,
#  'discovery': 5,
#  '(previously)': 1,
#  'unknown': 4,
#  '(this': 1,
#  'step': 3,
#  'knowledge': 6,
#  'databases).': 1,
#  'uses': 3,
#  'many': 9,
#  'different': 5,
#  'goals;': 1,
#  'hand,': 1,
#  'employs': 1,
#  '"unsupervised': 1,
#  'learning"': 1,
#  'preprocessing': 1,
#  'improve': 4,
#  'learner': 3,
#  'accuracy.': 1,
#  'Much': 1,
#  'confusion': 1,
#  'two': 7,
#  'communities': 1,
#  '(which': 1,
#  'conferences': 1,
#  'journals,': 1,
#  'ECML': 1,
#  'PKDD': 1,
#  'major': 1,
#  'exception)': 1,
#  'comes': 1,
#  'basic': 1,
#  'assumptions': 2,
#  'work': 1,
#  'with:': 1,
#  'usually': 2,
#  'evaluated': 1,
#  'reproduce': 1,
#  'knowledge,': 3,
#  '(KDD)': 1,
#  'key': 3,
#  'previously': 4,
#  'knowledge.': 2,
#  'Evaluated': 1,
#  'uninformed': 1,
#  '(unsupervised)': 1,
#  'method': 8,
#  'easily': 1,
#  'outperformed': 1,
#  'typical': 1,
#  'KDD': 1,
#  'task,': 1,
#  'cannot': 2,
#  'due': 1,
#  'unavailability': 1,
#  'data.\n': 1,
#  'has': 15,
#  'intimate': 1,
#  'ties': 1,
#  'optimization:': 1,
#  'formulated': 1,
#  'minimization': 1,
#  'loss': 3,
#  'examples.': 3,
#  'Loss': 1,
#  'functions': 2,
#  'express': 2,
#  'discrepancy': 1,
#  'trained': 7,
#  'actual': 1,
#  'instances': 4,
#  '(for': 1,
#  'classification,': 4,
#  'wants': 1,
#  'assign': 1,
#  'instances,': 1,
#  'correctly': 2,
#  'predict': 5,
#  'pre-assigned': 1,
#  'labels': 4,
#  'examples).': 1,
#  'difference': 3,
#  'fields': 1,
#  'arises': 1,
#  'generalization:': 1,
#  'minimize': 1,
#  'set,': 2,
#  'minimizing': 1,
#  'unseen': 3,
#  'samples.[12]\n': 1,
#  'fields.': 1,
#  'According': 1,
#  'Michael': 1,
#  'I.': 1,
#  'Jordan,': 1,
#  'ideas': 1,
#  'methodological': 1,
#  'principles': 1,
#  'tools,': 1,
#  'long': 1,
#  'pre-history': 1,
#  'statistics.[13]': 1,
#  'He': 1,
#  'suggested': 1,
#  'placeholder': 1,
#  'call': 2,
#  'overall': 2,
#  'field.[13]\n': 1,
#  'Leo': 1,
#  'Breiman': 1,
#  'distinguished': 1,
#  'modelling': 1,
#  'paradigms:': 1,
#  'algorithmic': 2,
#  'model,[14]': 1,
#  'wherein': 1,
#  '"algorithmic': 1,
#  'model"': 1,
#  'means': 1,
#  'less': 2,
#  'Random': 1,
#  'forest.\n': 1,
#  'Some': 2,
#  'statisticians': 1,
#  'adopted': 2,
#  'combined': 1,
#  'learning.[15]\n': 1,
#  'A': 7,
#  'core': 1,
#  'objective': 2,
#  'generalize': 1,
#  'experience.[2][16]': 1,
#  'Generalization': 1,
#  'this': 5,
#  'context': 3,
#  'accurately': 1,
#  'new,': 1,
#  'examples/tasks': 1,
#  'after': 5,
#  'experienced': 1,
#  'set.': 4,
#  'examples': 5,
#  'generally': 2,
#  'distribution': 1,
#  '(considered': 1,
#  'representative': 2,
#  'space': 2,
#  'occurrences)': 1,
#  'general': 2,
#  'about': 6,
#  'enables': 1,
#  'produce': 1,
#  'sufficiently': 1,
#  'accurate': 1,
#  'cases.\n': 1,
#  'branch': 1,
#  'theory.': 1,
#  'Because': 3,
#  'sets': 1,
#  'finite': 1,
#  'future': 1,
#  'uncertain,': 1,
#  'does': 3,
#  'not': 19,
#  'yield': 1,
#  'guarantees': 1,
#  'algorithms.': 1,
#  'Instead,': 2,
#  'probabilistic': 4,
#  'bounds': 1,
#  'quite': 1,
#  'common.': 1,
#  'bias–variance': 1,
#  'decomposition': 1,
#  'way': 4,
#  'quantify': 1,
#  'generalization': 2,
#  'error.\n': 1,
#  'best': 3,
#  'generalization,': 1,
#  'complexity': 5,
#  'hypothesis': 3,
#  'should': 1,
#  'match': 1,
#  'underlying': 2,
#  'If': 2,
#  'complex': 1,
#  'function,': 2,
#  'underfit': 1,
#  'increased': 1,
#  'response,': 1,
#  'error': 1,
#  'decreases.': 1,
#  'But': 1,
#  'too': 1,
#  'complex,': 1,
#  'subject': 1,
#  'overfitting': 1,
#  'poorer.[17]\n': 1,
#  'addition': 5,
#  'bounds,': 1,
#  'theorists': 1,
#  'time': 4,
#  'feasibility': 1,
#  'theory,': 4,
#  'computation': 1,
#  'considered': 1,
#  'feasible': 1,
#  'done': 1,
#  'polynomial': 3,
#  'There': 4,
#  'kinds': 2,
#  'results.': 1,
#  'Positive': 3,
#  'results': 2,
#  'show': 2,
#  'Negative': 3,
#  'classes': 2,
#  'time.\n': 1,
#  'differ': 1,
#  'approach,': 1,
#  'type': 2,
#  'output,': 2,
#  'intended': 2,
#  'solve.\n': 1,
#  'Supervised': 3,
#  'outputs.[18]': 1,
#  'consists': 2,
#  'Each': 2,
#  'example': 6,
#  'supervisory': 1,
#  'signal.': 1,
#  'model,': 3,
#  'array': 1,
#  'vector,': 2,
#  'sometimes': 2,
#  'called': 9,
#  'matrix.': 2,
#  'Through': 1,
#  'iterative': 1,
#  'associated': 3,
#  'inputs.[19]': 1,
#  'An': 6,
#  'optimal': 1,
#  'allow': 1,
#  'determine': 2,
#  'part': 2,
#  'accuracy': 3,
#  'over': 2,
#  'task.[6]\n': 1,
#  'regression.[20]': 1,
#  'values,': 1,
#  'numerical': 1,
#  'Similarity': 1,
#  'area': 2,
#  'similarity': 4,
#  'measures': 1,
#  'how': 2,
#  'objects': 2,
#  'are.': 1,
#  'applications': 3,
#  'ranking,': 1,
#  'recommendation': 3,
#  'systems,': 4,
#  'visual': 1,
#  'identity': 1,
#  'tracking,': 1,
#  'face': 1,
#  'verification,': 1,
#  'speaker': 1,
#  'verification.\n': 1,
#  'case': 1,
#  'semi-supervised': 1,
#  'algorithms,': 4,
#  'missing': 1,
#  'labels,': 1,
#  'nevertheless': 1,
#  'quality': 1,
#  'model.': 2,
#  'weakly': 1,
#  'noisy,': 1,
#  'limited,': 1,
#  'imprecise;': 1,
#  'however,': 1,
#  'cheaper': 1,
#  'obtain,': 1,
#  'resulting': 2,
#  'larger': 1,
#  'effective': 3,
#  'sets.[21]\n': 1,
#  'take': 5,
#  'therefore': 1,
#  'test': 7,
#  'labeled,': 1,
#  'categorized.': 1,
#  'Instead': 1,
#  'responding': 1,
#  'feedback,': 1,
#  'identify': 4,
#  'commonalities': 2,
#  'react': 1,
#  'presence': 2,
#  'absence': 1,
#  'piece': 1,
#  'central': 1,
#  'statistics,[22]': 1,
#  'though': 1,
#  'encompasses': 1,
#  'involving': 1,
#  'summarizing': 1,
#  'explaining': 1,
#  'features.\n': 1,
#  'Cluster': 1,
#  'assignment': 1,
#  'observations': 5,
#  'subsets': 3,
#  '(called': 1,
#  'clusters)': 1,
#  'so': 4,
#  'cluster': 3,
#  'according': 1,
#  'predesignated': 1,
#  'criteria,': 1,
#  'drawn': 1,
#  'clusters': 1,
#  'dissimilar.': 1,
#  'Different': 2,
#  'techniques': 7,
#  'defined': 2,
#  'metric': 1,
#  'evaluated,': 1,
#  'internal': 1,
#  'compactness,': 1,
#  'members': 2,
#  'cluster,': 1,
#  'separation,': 1,
#  'clusters.': 1,
#  'estimated': 1,
#  'graph': 2,
#  'connectivity.\n': 1,
#  'software': 1,
#  'agents': 1,
#  'ought': 1,
#  'actions': 1,
#  'environment': 2,
#  'maximize': 1,
#  'notion': 1,
#  'cumulative': 1,
#  'reward.': 1,
#  'Due': 1,
#  'generality,': 1,
#  'disciplines,': 1,
#  'control': 1,
#  'operations': 1,
#  'research,': 1,
#  'simulation-based': 1,
#  'optimization,': 1,
#  'multi-agent': 1,
#  'swarm': 1,
#  'genetic': 5,
#  'algorithms.[23][24]': 1,
#  'typically': 4,
#  'Markov': 1,
#  'Decision': 3,
#  'Process': 1,
#  '(MDP).': 1,
#  'Many': 1,
#  'programming': 6,
#  'techniques.[23][24][25]': 1,
#  'assume': 1,
#  'exact': 2,
#  'MDP,': 1,
#  'infeasible.[23][24]': 1,
#  'opponent.\n': 1,
#  'Several': 1,
#  'aim': 2,
#  'discovering': 3,
#  'better': 2,
#  'representations': 4,
#  'during': 1,
#  'training.[26]': 1,
#  'Classic': 1,
#  'principal': 1,
#  'components': 1,
#  'analysis.': 1,
#  'Feature': 3,
#  'representation': 5,
#  'attempt': 3,
#  'preserve': 1,
#  'transform': 1,
#  'makes': 1,
#  'useful,': 1,
#  'pre-processing': 1,
#  'before': 1,
#  'predictions.': 2,
#  'technique': 2,
#  'allows': 2,
#  'reconstruction': 1,
#  'coming': 1,
#  'data-generating': 1,
#  'distribution,': 1,
#  'necessarily': 2,
#  'faithful': 1,
#  'configurations': 1,
#  'implausible': 1,
#  'under': 5,
#  'distribution.': 1,
#  'replaces': 1,
#  'manual': 1,
#  'engineering,': 1,
#  'features': 6,
#  'them': 3,
#  'task.\n': 1,
#  'unsupervised.': 1,
#  'labeled': 2,
#  'neural': 5,
#  'networks,': 2,
#  'multilayer': 1,
#  'perceptrons,': 1,
#  'dictionary': 7,
#  'unlabeled': 2,
#  'independent': 1,
#  'component': 1,
#  'analysis,': 3,
#  'autoencoders,': 1,
#  'matrix': 1,
#  'factorization[27]': 1,
#  'forms': 2,
#  'clustering.[28][29][30]\n': 1,
#  'Manifold': 1,
#  'constraint': 2,
#  'low-dimensional.': 1,
#  'Sparse': 4,
#  'coding': 1,
#  'sparse,': 1,
#  'zeros.': 1,
#  'Multilinear': 1,
#  'subspace': 1,
#  'low-dimensional': 1,
#  'directly': 1,
#  'tensor': 1,
#  'multidimensional': 1,
#  'reshaping': 1,
#  'higher-dimensional': 1,
#  'vectors.[31]': 1,
#  'Deep': 2,
#  'multiple': 3,
#  'levels': 1,
#  'representation,': 1,
#  'hierarchy': 1,
#  'features,': 1,
#  'higher-level,': 1,
#  'abstract': 1,
#  'terms': 1,
#  '(or': 1,
#  'generating)': 1,
#  'lower-level': 1,
#  'features.': 2,
#  ...}

# %%
plt.pie(largest,labels=largest_words,shadow=False)
plt.show()

# %%
sb.barplot(largest_words,largest)
